# %% [markdown]
# <a href="https://colab.research.google.com/github/VijayShanmugan/GoogleColab/blob/main/1905122_Vijay_Shanmugan_S_Ex_2(m).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
df = pd.read_csv('https://raw.githubusercontent.com/VijayShanmugan/Datasets/main/Tokyo%20Medals%202021.csv')
df[:30]
# Out:
#                        Country  Gold Medal  ...  Total  Rank By Total
# 0     United States of America          39  ...    113              1
# 1   People's Republic of China          38  ...     88              2
# 2                        Japan          27  ...     58              5
# 3                Great Britain          22  ...     65              4
# 4                          ROC          20  ...     71              3
# 5                    Australia          17  ...     46              6
# 6                  Netherlands          10  ...     36              9
# 7                       France          10  ...     33             10
# 8                      Germany          10  ...     37              8
# 9                        Italy          10  ...     40              7
# 10                      Canada           7  ...     24             11
# 11                      Brazil           7  ...     21             12
# ...

# %%
plt.plot(df['Rank By Total'], df['Total'], color='blue', marker='o')
plt.title('Relationship between Rank and Medals', fontsize=16)
plt.xlabel('Rank', fontsize=14)
plt.ylabel('Total medals', fontsize=14)
plt.grid(True)
plt.show()

# %%
sns.regplot(x="Rank By Total", y="Total", data=df);

# %%
sns.set_style("whitegrid")
plt.figure(figsize=(16,6))

x=df["Rank By Total"][:20]
plt.title('Gold medals Vs Silver medals')

plt.xlabel('Rank')
plt.ylabel('Medals')

plt.plot(x,df["Gold Medal"][:20],"+--",c="r",label="Gold")
plt.plot(x,df["Silver Medal"][:20],"*--",c="b",label="Silver")
plt.plot(x,df["Bronze Medal"][:20],"_--",c="g",label="Bronze")

plt.legend()
plt.show()
